# %%
# %matplotlib inline
from gravFileIO import ReadInpFile as rif

# %%
rif('dyke_l.inp')
# Out:
# C:\Users\WAM\Anaconda2\lib\site-packages\matplotlib\figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
rif('dyke_v.inp')

# %%
rif('twob.inp')
